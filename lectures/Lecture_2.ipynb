# %% [markdown]
# # Лекция 2: Обзор алгоритмов ML для классификации и регрессии (решающие деревья, композиции деревьев). Кластеризация и снижение размерности. Обзор методов для кластеризации и снижения размерности

# %% [markdown]
# # Решающие Деревья

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Источник: https://www.mygreatlearning.com/blog/decision-tree-algorithm/

# %% [markdown]
# Есть много разных реализаций дерева, но суть их обычно в том, что берётся информационный критерии и максимизируется при каждом разбиении

# %% [markdown]
# Проблема тут в том, что одно дерево очень слабое. **Демократия спасёт нас!**

# %% [markdown]
# Можно учить не одно дерево, а много деревьев и сделать так, чтобы они проголосовали за варианты ответа. За какой вариант больше, тот и возьмём. **Но как учить?**. Если запускать постоянно на одной и той же выборке, то и ответ всегда будет один и тот же

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Источник: https://quantdare.com/what-is-the-difference-between-bagging-and-boosting/

# %%
import numpy as np

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.style.use(['science', 'no-latex',  'high-contrast'])

# %%
X = np.random.normal(0, 2, 100)
Y = 2 + X + X**2 + X**3 + np.random.normal(0, 5, size=100)
vals = np.linspace(-5, 5, 1000)
f = 2 + vals + vals**2 + vals**3

# %%
plt.figure(figsize=(15, 15))
plt.plot(X, Y, '.', label='Наблюдения')
plt.plot(vals, f, label='Истинная зависимость')
plt.xlabel('Признак (независимая переменная)')
plt.ylabel('Значение (зависимая переменная)')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100)

# %%
model.fit(X.reshape(-1, 1), Y.reshape(-1, 1).ravel())
# Out:
# RandomForestRegressor()

# %%
plt.figure(figsize=(15, 15))
plt.plot(X, Y, '.', label='Наблюдения')
plt.plot(vals, f, label='Истинная зависимость')
plt.plot(vals, model.predict(vals.reshape(-1, 1)), label='Линейная модель')
plt.xlabel('Признак (независимая переменная)')
plt.ylabel('Значение (зависимая переменная)')
plt.legend()
plt.show()

# %% [markdown]
# Минутка интересных фактов:
#
# - Оч плохая идея пытаться учить линейную регрессию для классификации
# - SVM, DecisionTrees, RandomForest, XGBoost работают как для задачи классификации, так и для рагрессии
# - Логистическая регрессия -- это линейный метод!!!
# - SVM может быть как линейным, так и нелинейным (всё зависит от ядра)

# %% [markdown]
# # Кластеризация

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Источник: https://www.geeksforgeeks.org/clustering-in-machine-learning/

# %% [markdown]
# ### Идея: Можно выстраивать цепочки, которые в определённый момент будут обрываться

# %% [markdown]
# ### DBSCAN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Источник: https://habr.com/ru/post/322034/

# %% [markdown]
# Демонстрация работы DBSCAN: https://www.kdnuggets.com/2020/04/dbscan-clustering-algorithm-machine-learning.html

# %% [markdown]
# ### Идея: Создать кластер так, чтобы дисперсия внутри класса была минимальной

# %% [markdown]
# ### K-MEANS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Источник: https://medium.com/analytics-vidhya/different-types-of-machine-learning-algorithm-b4f76b5730fd

# %% [markdown]
# Демонстрация работы K-MEANS: https://www.naftaliharris.com/blog/visualizing-k-means-clustering/

# %% [markdown]
# ### Спектральная кластеризация

# %% [markdown]
# https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B5%D0%BA%D1%82%D1%80%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D0%BA%D0%BB%D0%B0%D1%81%D1%82%D0%B5%D1%80%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D1%8F

# %% [markdown]
# # Проклятие размерности

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Источник: https://www.kdnuggets.com/2017/04/must-know-curse-dimensionality.html

# %% [markdown]
# # Снижение размерности

# %% [markdown]
# ## PCA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Источник: http://alexhwilliams.info/itsneuronalblog/2016/03/27/pca/

# %% [markdown]
# ## t-SNE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Источник: https://habr.com/ru/post/267041/
